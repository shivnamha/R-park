# %% [markdown]
# from wikipedia import wikipedia
# api =

# %%
import urllib2
from BeautifulSoup import BeautifulSoup
import pandas
URI="http://www.mapsofindia.com/roads/expressway/"
req = urllib2.urlopen(URI)
parsed_html = BeautifulSoup(req.read())
table = parsed_html.body.findAll('div', attrs={'class' : 'intnl_contr_link_block' } )

# %%
Exp = parsed_html.body.findAll('div', attrs={'class' : 'intrl_links'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0b15c5394639> in <module>()
# ----> 1 Exp = parsed_html.body.findAll('div', attrs={'class' : 'intrl_links'})
#
# NameError: name 'parsed_html' is not defined

# %%
URI='http://www.mapsofindia.com/driving-directions-maps/north-zone.html'

nr = urllib2.urlopen(URI)
URI = 'http://www.mapsofindia.com/driving-directions-maps/west-zone.html'
west = urllib2.urlopen(URI)
URI = 'http://www.mapsofindia.com/driving-directions-maps/south-zone.html'
south = urllib2.urlopen(URI)
URI = 'http://www.mapsofindia.com/driving-directions-maps/north-east-zone.html'
nr_east = urllib2.urlopen(URI)
URI = 'http://www.mapsofindia.com/driving-directions-maps/east-zone.html'
east = urllib2.urlopen(URI)
URI = 'http://www.mapsofindia.com/driving-directions-maps/central-zone.html'
center = urllib2.urlopen(URI)
parsed_html = BeautifulSoup(nr.read())
table = parsed_html.body.findAll('div', attrs={'class' : 'tablelink1' } )
print table

# %%
http://morth.nic.in/morthnoc/view_claifications_r.asp?EncHid=35712.86948

# %%
URI="List of National Highways in India by highway number"
from wikipedia import wikipedia
api = wikipedia.page(URI)
print api.content
# Out:
# The List of National Highways in India by Highway Number is a listing of National Highways of India sorted by highway number. On 28 April 2010 the Ministry of Road Transport and Highways officially published a new numbering system for the national highway network in the Gazette of the Government of India. It is a systematic numbering scheme based on the orientation and the geographic location of the highway. This was adopted to ensure more flexibility and consistency in the numbering of existing and new national highways.
# According to the new system, all north-south oriented highways will have even numbers increasing from the east to the west. Similarly, all east-west oriented highways will have odd numbers increasing from the north to the south of the country. In the new scheme, the single longest national highway will be NH 44 which will run from Srinagar to Kaniyakumari.
#
#
# == References ==

# %%
import urllib2
from BeautifulSoup import BeautifulSoup
URI = 'http://en.wikipedia.org/wiki/List_of_National_Highways_in_India_by_highway_number'
center = urllib2.urlopen(URI)
parsed_html = BeautifulSoup(center.read())
table = parsed_html.find('table', attrs={'class' : 'wikitable sortable' } )

# %%
List_NH = table.findAll('tr')
print List_NH[0].findALL('th')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-83b483644444> in <module>()
#       1 List_NH = table.findAll('tr')
# ----> 2 print List_NH[0].findALL('th')
#
# TypeError: 'NoneType' object is not callable

# %%
import urllib2
from BeautifulSoup import BeautifulSoup
URI="http://www.nhtis.org/tolllist.htm#"
#vehicle information
#http://www.knowindia.net/auto.html
#http://data.gov.in/catalog/total-number-registered-motor-vehicles-india#web_catalog_tabs_block_10
center = urllib2.urlopen(URI)
print center.read()
parsed_html = BeautifulSoup(center.read())
#print parsed_html
